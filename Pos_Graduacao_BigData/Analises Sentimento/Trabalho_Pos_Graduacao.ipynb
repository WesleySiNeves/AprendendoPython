# %%
#Importação das bibliotecas necessárias

import os
import string
import pandas as pd
import seaborn as sns
import numpy as np
from PIL import Image

import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import itertools
import collections

import re
import networkx as nx

import warnings
warnings.filterwarnings("ignore")

sns.set(font_scale=1.5)
sns.set_style("whitegrid")

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize

from wordcloud import WordCloud

# %%
pip install networkx
# Out:
# Collecting networkx
#   Downloading networkx-2.4-py3-none-any.whl (1.6 MB)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\pcsolution\appdata\roaming\python\python37\site-packages (from networkx) (4.4.1)
# Installing collected packages: networkx
# Successfully installed networkx-2.4
# Note: you may need to restart the kernel to use updated packages.

# %%
diretorio_arquivo = r'D:\Wesley\VersionCode\AprendendoPython\AprendendoPython\MachineLearning\Analises Sentimento\Datasets\avaliacoes_train.csv'

diretorio_pc_casa =r'D:\Wesley\Python\AprendendoPython\MachineLearning\Analises Sentimento\Datasets\avaliacoes_train.csv'

# %%
dados = pd.read_csv(diretorio_arquivo)

dados.head(10)
# Out:
#    ID  Avaliacao                        Titulo  \
# 0   3          0              Sempre muito bom
# 1   7          0                           Top
# 2  10          0         Excelente atendimento
# 3  11          0           Vista privilegiada
# 4  16          0                        Jantar
# 5  17          0         Boa opção para jantar
# 6  18          0                        Ótimo
# 7  26          0  Perfeito. Vista maravilhosa
# 8  27          0   Jantar numa ala reservada.
# 9  29          0           Melhor Da cidade!!!
#
#                                                Texto
# 0  Atendimento impecável  comida muito boa e rápi...
# 1  Um dos melhores de Brasília recomendo muito ms...
# 2  Nunca fui tão bem atendido em um restaurante  ...
# 3  Lugar maravilhoso com vista para o Lago Sul em...
# 4  Excelente  Janiel. Tanto sua receptividade  qu...
# 5  É um restaurante é grande e bem decorado. Ficá...
# 6  Numa 5f almoçamos no sistema self service com ...
# 7  Jantamos hj no restaurante. Atendimento nota 1...
# 8  Estivemos num jantar como uma extensão de um d...
# 9  Sempre uma boa surpresa  bom ambiente  ótimo s...

# %% [markdown]
# ## Limpeza de dados
# 1.remoção de pontuação
# 2.remoção de url
# 2.geração de token
# 2.remoção de stop_words
# 2.remoção de url

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\wesley.neves\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
custon_stop_words = ['nessa','todo','pra','vou','aqui','se','.',',','lá','vcs','pois','"',':','``']
punctuation = list(string.punctuation)
lista_stopwords  = set(stopwords.words('portuguese') + punctuation + custon_stop_words+ ['rt', 'via'])

# %% [markdown]
# ### funçoes

# %%
def remove_url(texto):
    return re.sub(r'http\S+', '', texto)

# %%
def set_tokenize(texto):
    return word_tokenize(texto)

# %%
def remove_stop_Words(texto,lista_stopwords):
    palavras =set_tokenize(texto)
    palavras_sem_stopwords = [palavra.lower() for palavra in palavras if palavra.lower() not in lista_stopwords]
    return (palavras_sem_stopwords)

# %%
def remove_caracteres_especiais(texto):
    punctuations = '''!()-![]{};:+'"\,<>./?@#$%^&*_~'''
    remove = ''.join([i for i in texto if not i in punctuations])
    remove_1 =  re.sub(r" ?\([^)]+\)", "", remove)
    remove_2 =''.join(remove_1).replace("'", " ")
    remove_3 =''.join(remove_2).replace("[", " ")
    remove_4 =''.join(remove_3).replace("]", " ")
    return str(remove_4)

# %%
### recuperar o conteudo a ser trabalhado
def normaliza_dados(texto,lista_stopwords):
    valor = remove_url(texto)
    valor_2 = remove_caracteres_especiais(valor)
    remove =remove_stop_Words(valor_2,lista_stopwords)

    return remove

# %% [markdown]
# ## Mostra o antes e o depois do processamento

# %%
dados[['Titulo','Texto']].head(2)
# Out:
#              Titulo                                              Texto
# 0  Sempre muito bom  Atendimento impecável  comida muito boa e rápi...
# 1               Top  Um dos melhores de Brasília recomendo muito ms...

# %% [markdown]
# ## Limpeza dos dados

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\wesley.neves\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ## Faz o clone do dataframe para limpeza

# %%
clone = pd.DataFrame.copy(dados)

# %%
clone["ConteudoLimpo"] =''
clone["Bigrama"] =''

clone.head(5)
# Out:
#    ID  Avaliacao                 Titulo  \
# 0   3          0       Sempre muito bom
# 1   7          0                    Top
# 2  10          0  Excelente atendimento
# 3  11          0    Vista privilegiada
# 4  16          0                 Jantar
#
#                                                Texto ConteudoLimpo Bigrama
# 0  Atendimento impecável  comida muito boa e rápi...
# 1  Um dos melhores de Brasília recomendo muito ms...
# 2  Nunca fui tão bem atendido em um restaurante  ...
# 3  Lugar maravilhoso com vista para o Lago Sul em...
# 4  Excelente  Janiel. Tanto sua receptividade  qu...

# %%
clone['ConteudoLimpo'] = [normaliza_dados(texto,lista_stopwords) for texto in clone['Texto']]

# %%
clone.head(5)
# Out:
#    ID  Avaliacao                 Titulo  \
# 0   3          0       Sempre muito bom
# 1   7          0                    Top
# 2  10          0  Excelente atendimento
# 3  11          0    Vista privilegiada
# 4  16          0                 Jantar
#
#                                                Texto  \
# 0  Atendimento impecável  comida muito boa e rápi...
# 1  Um dos melhores de Brasília recomendo muito ms...
# 2  Nunca fui tão bem atendido em um restaurante  ...
# 3  Lugar maravilhoso com vista para o Lago Sul em...
# 4  Excelente  Janiel. Tanto sua receptividade  qu...
#
#                                        ConteudoLimpo Bigrama
# 0  [atendimento, impecável, comida, boa, rápida, ...
# 1  [melhores, brasília, recomendo, msm, podem, ir...
# 2  [nunca, tão, bem, atendido, restaurante, princ...
# 3  [lugar, maravilhoso, vista, lago, sul, ambient...
# 4  [excelente, janiel, tanto, receptividade, aten...

# %% [markdown]
# ## Calcular a frequencia de palavras

# %%
all_comentarios_list = list(itertools.chain(*clone['ConteudoLimpo']))

# Create counter
counts_list = collections.Counter(all_comentarios_list)


dataframe = pd.DataFrame(counts_list.most_common(20),
                             columns=['termo', 'quantidade'])

dataframe.head(10)
# Out:
#          termo  quantidade
# 0  atendimento       11963
# 1       comida       11829
# 2          bem        9399
# 3  restaurante        7757
# 4          bom        7716
# 5     ambiente        7677
# 6    excelente        6564
# 7       pratos        5640
# 8          boa        5144
# 9    agradável        4672

# %% [markdown]
# ## analisamos os termos mais encontrados

# %%
fig, ax = plt.subplots(figsize=(8, 8))

# Plot horizontal bar graph
dataframe.sort_values(by='quantidade').plot.barh(x='termo',
                      y='quantidade',
                      ax=ax,
                      color="purple")

ax.set_title("Quantidade de palavras por termo")

plt.show()

# %% [markdown]
# ## explorando os bigramas

# %%
clone['Bigrama'] =clone['ConteudoLimpo'].apply(lambda row: list(nltk.ngrams(row,2)))

# %%
clone.head(2)
# Out:
#    ID  Avaliacao            Titulo  \
# 0   3          0  Sempre muito bom
# 1   7          0               Top
#
#                                                Texto  \
# 0  Atendimento impecável  comida muito boa e rápi...
# 1  Um dos melhores de Brasília recomendo muito ms...
#
#                                        ConteudoLimpo  \
# 0  [atendimento, impecável, comida, boa, rápida, ...
# 1  [melhores, brasília, recomendo, msm, podem, ir...
#
#                                              Bigrama
# 0  [(atendimento, impecável), (impecável, comida)...
# 1  [(melhores, brasília), (brasília, recomendo), ...

# %%
bigrams = list(itertools.chain(*clone['Bigrama']))

bigram_counts = collections.Counter(bigrams)


dataframe_bigrama = pd.DataFrame(bigram_counts.most_common(1000),
                             columns=['bigram', 'count'])

dataframe_bigrama.head(60)
# Out:
#                       bigram  count
# 0      (ambiente, agradável)   1922
# 1               (vale, pena)   1906
# 2              (comida, boa)   1608
# 3         (atendimento, bom)   1385
# 4         (bom, atendimento)   1224
# 5              (coco, bambu)   1148
# 6              (frutos, mar)   1106
# 7   (excelente, atendimento)    961
# 8   (atendimento, excelente)    910
# 9       (ótimo, atendimento)    908
# 10       (comida, excelente)    868
# 11            (preço, justo)    867
# 12           (bem, servidos)    777
# 13  (camarão, internacional)    724
# 14       (comida, deliciosa)    721
# 15             (pratos, bem)    651
# 16     (comida, maravilhosa)    636
# 17             (vista, lago)    633
# 18              (carne, sol)    628
# 19           (lago, paranoá)    621
# 20      (comida, nordestina)    509
# 21             (boa, comida)    500
# 22            (música, vivo)    486
# 23             (happy, hour)    474
# 24        (comida, saborosa)    470
# 25       (excelente, comida)    466
# 26           (carta, vinhos)    464
# 27     (atendimento, comida)    447
# 28            (bem, servido)    437
# 29        (super, agradável)    419
# 30        (local, agradável)    415
# 31         (cerveja, gelada)    414
# 32         (comida, gostosa)    414
# 33       (agradável, comida)    406
# 34               (lago, sul)    403
# 35     (atendimento, garçom)    397
# 36  (agradável, atendimento)    384
# 37          (muitas, opções)    376
# 38       (grande, variedade)    356
# 39        (lugar, agradável)    355
# 40         (ambiente, super)    353
# 41             (comida, bem)    347
# 42          (bem, atendidos)    332
# 43        (custo, benefício)    332
# 44              (4, pessoas)    331
# 45                (nota, 10)    328
# 46           (bem, decorado)    326
# 47            (ótima, opção)    324
# 48       (cardápio, variado)    324
# 49          (pena, conhecer)    323
# 50           (ambiente, bem)    322
# 51  (ambiente, aconchegante)    317
# 52  (atendimento, impecável)    314
# 53            (bem, servida)    313
# 54      (atendimento, ótimo)    313
# 55        (super, recomendo)    312
# 56         (bem, localizado)    311
# 57       (variedade, pratos)    308
# 58           (self, service)    304
# 59             (bom, comida)    302

# %% [markdown]
# ## gerar um grafico dos bigramas

# %%
# Create dictionary of bigrams and their counts
d = dataframe_bigrama.head(20).set_index('bigram').T.to_dict('records')

# Create network plot 
G = nx.Graph()

# Create connections between nodes
for k, v in d[0].items():
    G.add_edge(k[0], k[1], weight=(v * 2))

G.add_node("china", weight=100)
fig, ax = plt.subplots(figsize=(16, 8))

pos = nx.spring_layout(G, k=1)

# Plot networks
nx.draw_networkx(G, pos,
                 font_size=16,
                 width=3,
                 edge_color='grey',
                 node_color='purple',
                 with_labels = False,
                 ax=ax)

# Create offset labels
for key, value in pos.items():
    x, y = value[0]+.135, value[1]+.075
    ax.text(x, y,
            s=key,
            bbox=dict(facecolor='red', alpha=0.25),
            horizontalalignment='center', fontsize=14)
    
plt.show()

# %% [markdown]
# # Nuvens de palavras

# %% [markdown]
# ## gera todo o conteudo apenas em uma string

# %% [markdown]
# ## Analise de sentimentos

# %%
clone['Sentimento']=''

# %%
positivos =[]
negativos=[]
positivos.append(('ambiente', 'agradável'))
positivos.append(('vale', 'pena'))
positivos.append(('comida', 'boa'))
positivos.append(('atendimento', 'bom'))
positivos.append(('bom', 'atendimento'))
positivos.append(('excelente', 'atendimento'))
positivos.append(('atendimento', 'excelente'))
positivos.append(('comida', 'deliciosa'))

positivos.append(('boa', 'comida'))
positivos.append(('super', 'agradável'))
positivos.append(('sempre', 'boa'))
positivos.append(('sempre', 'bom'))
positivos.append(('bom', 'atendimento'))
positivos.append(('pratos', 'gostosos'))
positivos.append(('atendimento', 'atencioso'))
positivos.append(('lugar', 'maravilhoso'))
positivos.append(('tudo', 'bom'))
positivos.append(('bem', 'atendido'))
positivos.append(('cardápio', 'delicioso'))
positivos.append(('excelentes', 'pratos'))
positivos.append(('excelente', 'prato'))
positivos.append(('gostamos', 'sempre'))
positivos.append(('super', 'indico'))
positivos.append(('local', 'maravilhoso'))
positivos.append(('excelente', 'restaurante'))
positivos.append(('jantar', 'perfeito'))
positivos.append(('jantar', 'perfeito'))
positivos.append(('sempre', 'deliciosa'))
positivos.append(('lugar', 'otimo'))
positivos.append(('execelente', 'lugar'))
positivos.append(('ótimo', 'atendimento'))
positivos.append(('atendimento', 'perfeito'))
positivos.append(('comida', 'maravilhosa'))
positivos.append(('bom', 'tempero'))
positivos.append(('restaurante', 'aconchegante'))
positivos.append(('local', 'agradável'))
positivos.append(('comida', 'excelente'))
positivos.append(('excelente', 'comida'))
positivos.append(('ótimo', 'ambiente'))
positivos.append(('ótimo', 'jantar'))
positivos.append(('sempre', 'agradável'))
positivos.append(('atendimento', 'maravilhoso'))
positivos.append(('lugar', 'completo'))
positivos.append(('excelente', 'tarde'))
positivos.append(('(bom', 'recomendo'))

positivos.append(('atendimento', 'top'))
positivos.append(('refeição', 'ótima'))
positivos.append(('jantar', 'maravilhoso'))

positivos.append(('ótimo', 'restaurante'))
positivos.append(('boa', 'comida'))
positivos.append(('comida', 'saborosa'))
positivos.append(('excelente', 'comida'))
positivos.append(('super', 'agradável'))
positivos.append(('ótimo', 'almoço'))
positivos.append(('gostei', 'atendimento'))
positivos.append(('noite', 'maravilhosa'))

positivos.append(('podem', 'ir'))
positivos.append(('bem', 'atendidos'))
positivos.append(('qualidade', 'atendimento'))
positivos.append(('excelente', 'vista'))
positivos.append(('boa', 'recomendo'))

positivos.append(('ambiente', 'tranquilo'))
positivos.append(('localização', 'privilegiada'))
positivos.append(('sempre', 'sensacional'))
positivos.append(('super', 'recomendo'))
positivos.append(('sempre', 'atenciosos'))
positivos.append(('bom', 'equipe'))
positivos.append(('excelente', 'garçom'))
positivos.append(('parabéns', 'atendimento'))

negativos.append(('deixou', 'desejar'))
negativos.append(('chegou', 'fria'))
negativos.append(('comida', 'fria'))
negativos.append(('atendimento', 'ruim'))
negativos.append(('última', 'vez'))

# %%
def avalia_comentario(texto,positivos,negativos):
    for bigrama in list(texto):
        if(positivos.count(bigrama) > 0 and negativos.count(bigrama) == 0):
            return 'positivo'
            break
        if(negativos.count(bigrama) > 0):
            return 'negativo'
            break
        # else:
        #     return ''

# %%
clone['Sentimento'] =''
clone['Sentimento'] =clone['Bigrama'].apply(lambda row: avalia_comentario(row,positivos,negativos))

# %%
dataframe_positvo = clone.loc[clone['Sentimento'] =='positivo']

dataframe_negativo = clone.loc[clone['Sentimento'] =='negativo']

dataframe_nao_avaliado = clone.loc[clone['Sentimento'].isnull()]

dataframe_positvo.set_index('ID', inplace=True)
dataframe_negativo.set_index('ID', inplace=True)
dataframe_nao_avaliado.set_index('ID', inplace=True)

# %%
# Positivos: 13340 Negativos 255 Nao Avaliado 15385

print('Positivos:',len(dataframe_positvo), 'Negativos',len(dataframe_negativo),'Nao Avaliado',len(dataframe_nao_avaliado))
# Out:
# Positivos: 13340 Negativos 255 Nao Avaliado 15385

# %%
#  (boa, comida)
# Out:
# 0

# %%
termos_negativos =''

for index, row in dataframe_negativo.iterrows():
    conteudo_1 = dataframe_negativo['ConteudoLimpo'][index]
    for item in conteudo_1:
        termos_negativos  += item +' '

# %%
termos_positivos =''

for index, row in dataframe_positvo.iterrows():
    conteudo_2 = dataframe_positvo['ConteudoLimpo'][index]
    for item in conteudo_2:
        termos_positivos  += item +' '

# %%
termos_nao_avaliados =''

for index, row in dataframe_nao_avaliado.iterrows():
    conteudo_3 = dataframe_nao_avaliado['ConteudoLimpo'][index]
    for item in conteudo_3:
        termos_nao_avaliados  += item +' '

# %%
mapa_cores =ListedColormap(['orange','green','red','magenta'])

nuvem = WordCloud(background_color='white',
                colormap=mapa_cores,
                max_words =200,
                 max_font_size=100,width = 1520, height = 535).generate_from_text(str(termos_negativos))
plt.figure(figsize=(16,9))
plt.imshow(nuvem,interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
mapa_cores =ListedColormap(['orange','green','red','magenta'])

nuvem = WordCloud(background_color='white',
                colormap=mapa_cores,
                max_words =300,
                 max_font_size=100,width = 1520, height = 535).generate_from_text(str(termos_positivos))
plt.figure(figsize=(16,9))
plt.imshow(nuvem,interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
mapa_cores =ListedColormap(['orange','green','red','magenta'])

nuvem = WordCloud(background_color='white',
                colormap=mapa_cores,
                max_words =200,
                 max_font_size=100,width = 1520, height = 535).generate_from_text(str(termos_nao_avaliados))
plt.figure(figsize=(16,9))
plt.imshow(nuvem,interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
dataframe_nao_avaliado[10:50]
# Out:
#      Avaliacao                                             Titulo  \
# ID
# 174          0                                        Aniversário
# 196          0                        Boa pedida  mas não é único
# 197          0                             Um dos melhores em Bsb
# 205          0                                         Coco Bambu
# 208          0                                      Fantástico!!
# 215          0                   Atendimento perfeito do Azevedo!
# 247          0                                            Almoço
# 271          0                                       Vale a pena!
# 280          0                                            Almoço
# 281          0                                            Almoço
# 282          0                                 Coco bambu asa Sul
# 287          0                                  Almoço em Família
# 300          0               Comemorando aniversário de casamento
# 316          1                                   local agradavel.
# 327          0                                          Casamento
# 359          1           pratos excelentes  serviço decepcionante
# 360          0          A comida é farta e de qualidade excelente
# 380          0                                        Aniversário
# 385          1                               Nada de excepcional
# 392          0                                  Pratos perfeitos!
# 394          0                                      Ótima comida.
# 410          0                                         Recomendo!
# 416          0                                            Amo D+!
# 429          0  Amei as instalações  luzes frescas e modernas ...
# 494          0                                             Jantar
# 522          0                                      Melhor garçom
# 534          0                        Ótima comida com camarão!!!
# 555          0                         Bom para comer com Família
# 558          0                                             Almoço
# 561          1                                              Comum
# 562          0                                Jantar entre amigos
# 567          0                                            Almoço
# 602          0                                        Atendimento
# 605          0                                Que sobremesa 10!!!
# 606          0                                        Aniversário
# 615          0                              Excelente experiência
# 618          0                                             almoço
# 625          0                                             Almoço
# 637          0                              Aniversário da Janine
# 663          0                                             Almoço
#
#                                                  Texto  \
# ID
# 174  Fomos recebidos da melhor maneira possível pel...
# 196  CocoBambu do Brasília Shopping: jantamos aqui ...
# 197  Sem dúvida um dos melhores restaurantes em Bra...
# 205  Mais um dia com experiência positiva  em todos...
# 208  Patrick de longe o melhor garçom!! Camarão int...
# 215  Sempre uma ótima experiência! Em particular o ...
# 247  Para mim o Coco Bambu é um dos melhores restau...
# 271  A comida é sensacional e o astral do lugar mel...
# 280  Muito bom. Fomos atenciosamente atendidos pelo...
# 281  Almoço delicioso. Serviço do garçom Patrick é ...
# 282  Ótima comida  atendimento foi fantástico prest...
# 287  Viemos fazer um almoço bem rápido porque nosso...
# 300  Adoramos o atendimento do sr. marcos  o prato ...
# 316  Fui a este restaurante para conhecer e saboria...
# 327  Patrick  Santos e Henio atenderam de forma imp...
# 359  os pratos do menu são incríveis! saborosos e b...
# 360  O Camarão a milanesa sdalpicados com gergelim ...
# 380  Vanos com frequência ao coco bambu  Gosto da c...
# 385  Pedimos o prato Camarão Internacional  mas vei...
# 392  Pratos muito bem preparados  com ingredientes ...
# 394  Muito bom  ótimas opções no cardápio. Ponto ne...
# 410  Gosto do ambiente  do atendimento e da comida....
# 416  Excelente ambiente. Cardápio maravilhoso! Aten...
# 429  A comida  o ambiente e o atendimento são ótimo...
# 494  Comida 10 Atendimento 10 Tudo 10 Musica agrave...
# 522  Além do restaurante e a comida serem maravilho...
# 534  Esse restaurante é muito frequentado pelas pes...
# 555  Mesas redondas e boas comidas. Camarão interna...
# 558  A comida  o atendimento é o espaço são ótimosó...
# 561  Barulho  lotação além da conta  comida razoáve...
# 562  Prato excelente  muito bem servido  atendiment...
# 567  Comida  ambiente e atendimento(por patrick) se...
# 602  O atendimento pelo garçom Douglas foi excelent...
# 605  Cheesecake maravilhoso!!!! Calda no ponto cert...
# 606  Gostei muito do espaço e da comida. Eu e minha...
# 615  Escolhemos o camarao jangadeiro e o brownie de...
# 618  Ambiente muito legal  comida e atendimento imp...
# 625  Prato Itamaracá maravilhoso e com preço acessí...
# 637  Nosso almoço foi maravilhoso e fomos atendidas...
# 663  Comida ótima  ambiente  música e atendimento d...
#
#                                          ConteudoLimpo  \
# ID
# 174  [recebidos, melhor, maneira, possível, patrick...
# 196  [cocobambu, brasília, shopping, jantamos, 2, n...
# 197  [dúvida, melhores, restaurantes, brasilia, com...
# 205  [dia, experiência, positiva, todos, sentidos, ...
# 208  [patrick, longe, melhor, garçom, camarão, inte...
# 215  [sempre, ótima, experiência, particular, atend...
# 247  [mim, coco, bambu, melhores, restaurantes, bra...
# 271  [comida, sensacional, astral, lugar, melhor, a...
# 280  [bom, atenciosamente, atendidos, garçon, eliom...
# 281  [almoço, delicioso, serviço, garçom, patrick, ...
# 282  [ótima, comida, atendimento, fantástico, prest...
# 287  [viemos, fazer, almoço, bem, rápido, porque, t...
# 300  [adoramos, atendimento, sr, marcos, prato, per...
# 316  [restaurante, conhecer, saboriar, famoso, cama...
# 327  [patrick, santos, henio, atenderam, forma, imp...
# 359  [pratos, menu, incríveis, saborosos, bem, serv...
# 360  [camarão, milanesa, sdalpicados, gergelim, pet...
# 380  [vanos, frequência, coco, bambu, gosto, comida...
# 385  [pedimos, prato, camarão, internacional, veio,...
# 392  [pratos, bem, preparados, ingredientes, fresqu...
# 394  [bom, ótimas, opções, cardápio, ponto, negativ...
# 410  [gosto, ambiente, atendimento, comida, caipiri...
# 416  [excelente, ambiente, cardápio, maravilhoso, a...
# 429  [comida, ambiente, atendimento, ótimos, locali...
# 494  [comida, 10, atendimento, 10, tudo, 10, musica...
# 522  [além, restaurante, comida, serem, maravilhoso...
# 534  [restaurante, frequentado, pessoas, cidade, se...
# 555  [mesas, redondas, boas, comidas, camarão, inte...
# 558  [comida, atendimento, espaço, ótimosó, atendid...
# 561  [barulho, lotação, além, conta, comida, razoáv...
# 562  [prato, excelente, bem, servido, atendimento, ...
# 567  [comida, ambiente, atendimentopor, patrick, se...
# 602  [atendimento, garçom, douglas, excelente, tran...
# 605  [cheesecake, maravilhoso, calda, ponto, certo,...
# 606  [gostei, espaço, comida, família, aproveitamos...
# 615  [escolhemos, camarao, jangadeiro, brownie, cho...
# 618  [ambiente, legal, comida, atendimento, impecáv...
# 625  [prato, itamaracá, maravilhoso, preço, acessív...
# 637  [almoço, maravilhoso, atendidas, queiroz, aniv...
# 663  [comida, ótima, ambiente, música, atendimento,...
#
#                                                Bigrama Sentimento
# ID
# 174  [(recebidos, melhor), (melhor, maneira), (mane...       None
# 196  [(cocobambu, brasília), (brasília, shopping), ...       None
# 197  [(dúvida, melhores), (melhores, restaurantes),...       None
# 205  [(dia, experiência), (experiência, positiva), ...       None
# 208  [(patrick, longe), (longe, melhor), (melhor, g...       None
# 215  [(sempre, ótima), (ótima, experiência), (exper...       None
# 247  [(mim, coco), (coco, bambu), (bambu, melhores)...       None
# 271  [(comida, sensacional), (sensacional, astral),...       None
# 280  [(bom, atenciosamente), (atenciosamente, atend...       None
# 281  [(almoço, delicioso), (delicioso, serviço), (s...       None
# 282  [(ótima, comida), (comida, atendimento), (aten...       None
# 287  [(viemos, fazer), (fazer, almoço), (almoço, be...       None
# 300  [(adoramos, atendimento), (atendimento, sr), (...       None
# 316  [(restaurante, conhecer), (conhecer, saboriar)...       None
# 327  [(patrick, santos), (santos, henio), (henio, a...       None
# 359  [(pratos, menu), (menu, incríveis), (incríveis...       None
# 360  [(camarão, milanesa), (milanesa, sdalpicados),...       None
# 380  [(vanos, frequência), (frequência, coco), (coc...       None
# 385  [(pedimos, prato), (prato, camarão), (camarão,...       None
# 392  [(pratos, bem), (bem, preparados), (preparados...       None
# 394  [(bom, ótimas), (ótimas, opções), (opções, car...       None
# 410  [(gosto, ambiente), (ambiente, atendimento), (...       None
# 416  [(excelente, ambiente), (ambiente, cardápio), ...       None
# 429  [(comida, ambiente), (ambiente, atendimento), ...       None
# 494  [(comida, 10), (10, atendimento), (atendimento...       None
# 522  [(além, restaurante), (restaurante, comida), (...       None
# 534  [(restaurante, frequentado), (frequentado, pes...       None
# 555  [(mesas, redondas), (redondas, boas), (boas, c...       None
# 558  [(comida, atendimento), (atendimento, espaço),...       None
# 561  [(barulho, lotação), (lotação, além), (além, c...       None
# 562  [(prato, excelente), (excelente, bem), (bem, s...       None
# 567  [(comida, ambiente), (ambiente, atendimentopor...       None
# 602  [(atendimento, garçom), (garçom, douglas), (do...       None
# 605  [(cheesecake, maravilhoso), (maravilhoso, cald...       None
# 606  [(gostei, espaço), (espaço, comida), (comida, ...       None
# 615  [(escolhemos, camarao), (camarao, jangadeiro),...       None
# 618  [(ambiente, legal), (legal, comida), (comida, ...       None
# 625  [(prato, itamaracá), (itamaracá, maravilhoso),...       None
# 637  [(almoço, maravilhoso), (maravilhoso, atendida...       None
# 663  [(comida, ótima), (ótima, ambiente), (ambiente...       None

# %%
# Out:
# True
# True
# False
# False
# False
# False
# False
# False

# %%
('melhores', 'restaurantes')
