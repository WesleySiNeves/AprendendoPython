# %%
import pandas as pd

data = pd.read_csv(r'D:\Wesley\Python\AprendendoPython\MachineLearning\Olimpiadas\athlete_events.csv')

data.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %% [markdown]
# ## renomear colunas de um dataframe
# inplace = True  e  para executar o comando realmente e não somente mostrar

# %%
data.rename(columns ={'Name':'Nome','Sex':'Sexo','Age':'Idade','Height':'Altura','Weight':'Peso'},inplace=True)

# %%
data.head()
# Out:
#    ID                      Nome Sexo  Idade  Altura  Peso            Team  \
# 0   1                 A Dijiang    M   24.0   180.0  80.0           China
# 1   2                  A Lamusi    M   23.0   170.0  60.0           China
# 2   3       Gunnar Nielsen Aaby    M   24.0     NaN   NaN         Denmark
# 3   4      Edgar Lindenau Aabye    M   34.0     NaN   NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink    F   21.0   185.0  82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %% [markdown]
# ## identificando alguns insides

# %% [markdown]
# ## retorna o resultado agrupado de cada coluna , nesse caso temos a quantidade de atletas do sexo F e M
# Atletas sexo M = 196594
# Atletas sexo F = 74522

# %%
data.Sexo.value_counts()
# Out:
# M    196594
# F     74522
# Name: Sexo, dtype: int64

# %% [markdown]
# ## Olimpiadas com maior quantidade de atletas

# %%
data.City.value_counts()
# Out:
# London                    22426
# Athina                    15556
# Sydney                    13821
# Atlanta                   13780
# Rio de Janeiro            13688
# Beijing                   13602
# Barcelona                 12977
# Los Angeles               12423
# Seoul                     12037
# Munich                    10304
# Montreal                   8641
# Mexico City                8588
# Helsinki                   8270
# Roma                       8119
# Tokyo                      7702
# Moskva                     7191
# Paris                      7169
# Berlin                     6506
# Amsterdam                  4992
# Sochi                      4891
# Melbourne                  4829
# Vancouver                  4402
# Torino                     4382
# Stockholm                  4338
# Antwerpen                  4292
# Salt Lake City             4109
# Innsbruck                  3639
# Nagano                     3605
# Albertville                3436
# ...

# %% [markdown]
# ## excluir colunas

# %%
data.head(2)
# Out:
#    ID       Nome Sexo  Idade  Altura  Peso   Team  NOC        Games  Year  \
# 0   1  A Dijiang    M   24.0   180.0  80.0  China  CHN  1992 Summer  1992
# 1   2   A Lamusi    M   23.0   170.0  60.0  China  CHN  2012 Summer  2012
#
#    Season       City       Sport                         Event Medal
# 0  Summer  Barcelona  Basketball   Basketball Men's Basketball   NaN
# 1  Summer     London        Judo  Judo Men's Extra-Lightweight   NaN

# %%
data.drop('ID',axis=1,inplace = True)
data.drop('City',axis=1,inplace = True)

# %%
data.head(2)
# Out:
#         Nome Sexo  Idade  Altura  Peso   Team  NOC        Games  Year  Season  \
# 0  A Dijiang    M   24.0   180.0  80.0  China  CHN  1992 Summer  1992  Summer
# 1   A Lamusi    M   23.0   170.0  60.0  China  CHN  2012 Summer  2012  Summer
#
#         Sport                         Event Medal
# 0  Basketball   Basketball Men's Basketball   NaN
# 1        Judo  Judo Men's Extra-Lightweight   NaN

# %% [markdown]
# ## trabalhando com Graficos

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## grafico de Histograma , traz a distribuição de dados

# %%
data.hist(column='Idade',bins=100)
plt.show()

# %% [markdown]
# ## box plot

# %%
data.boxplot(column='Idade')
plt.show()

# %%
data.boxplot(column=['Idade','Altura','Peso'])
plt.show()
