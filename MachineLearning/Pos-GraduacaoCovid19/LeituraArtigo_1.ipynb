# %% [markdown]
# ## https://www.pyimagesearch.com/2020/03/16/detecting-covid-19-in-x-ray-images-with-keras-tensorflow-and-deep-learning/

# %% [markdown]
# ## Neste tutorial, você aprenderá como detectar automaticamente o COVID-19 em um conjunto de dados de imagem de raio-X criado à mão usando Keras, TensorFlow e Deep Learning.

# %% [markdown]
# ## Como seres humanos, não há nada mais aterrorizante do que o desconhecido
#
#
#
# ## Dentro do tutorial de hoje, você aprenderá como:
#
# ## Amostra de um conjunto de dados de imagens de raios-X de código aberto para pacientes que apresentaram resultado positivo para COVID-19
#
#
# ## Amostra de imagens de raios X “normais” (não infectadas) de pacientes saudáveis
#
# ## Treine uma CNN para detectar automaticamente o COVID-19 em imagens de raios-X através do conjunto de dados que criamos
#
# ## Avalie os resultados de uma perspectiva educacional

# %% [markdown]
# ## Simplificando: você não precisa de um diploma em medicina para causar impacto no campo da medicina  - profissionais de aprendizado profundo que trabalham em estreita colaboração com médicos e profissionais da área médica podem resolver problemas complexos, salvar vidas e tornar o mundo um lugar melhor.

# %% [markdown]
# ## Como o COVID-19 pode ser detectado em imagens de raios-X?

# %%
from IPython.display import Image
Image(r'imagens\imagenPacienteComCovid.PNG')

# %% [markdown]
# ## Para os fins deste tutorial, pensei em explorar imagens de raios-X, pois os médicos freqüentemente usam raios-X e tomografias computadorizadas para diagnosticar pneumonia, inflamação nos pulmões, abscessos e / ou linfonodos aumentados.

# %% [markdown]
# ### Como o COVID-19 ataca as células epiteliais que revestem nosso trato respiratório, podemos usar raios-X para analisar a saúde dos pulmões de um paciente
#
# ### E, como quase todos os hospitais possuem máquinas de raios X, pode ser possível usar raios X para testar o COVID-19 sem os kits de teste dedicados.
#
# Uma desvantagem é que a análise de raios-X requer um especialista em radiologia e leva um tempo significativo - o que é precioso quando as pessoas estão doentes em todo o mundo. Portanto, é necessário desenvolver um sistema de análise automatizado para economizar aos profissionais médicos um tempo valioso.

# %%
from IPython.display import Image
Image(r'imagens\iamgensVariosRx.PNG')

# %% [markdown]
# ## O conjunto de dados de imagem de raios-X COVID-19 que usaremos para este tutorial foi curado pelo Dr. Joseph Cohen , um pós-doutorado na Universidade de Montreal
# https://josephpcohen.com/w/
#
# ## git hub dos dados
# https://josephpcohen.com/w/public-covid19-dataset/
#
# https://github.com/ieee8023/covid-chestxray-dataset

# %% [markdown]
# ## Dentro do repositório, você encontrará exemplos de casos COVID-19, além de MERS, SARS e ARDS.

# %% [markdown]
# ## Para criar o conjunto de dados de imagem de raio-x COVID-19 para este tutorial, eu:
#
# 1) Analisou o metadata.csv arquivo encontrado no repositório do Dr. Cohen.
#
# 2) Selecionadas todas as linhas que são:
# Positivo para COVID-19 (ou seja, ignorando os casos MERS, SARS e ARDS).
#
# Vista posterior-posterior (AP) dos pulmões. Eu usei a visualização da AF como, que eu saiba, essa era a usada para meus casos "saudáveis", conforme discutido abaixo; no entanto, tenho certeza de que um profissional médico será capaz de me esclarecer e me corrigir se eu estiver incorreto (o que muito bem posso ser, isso é apenas um exemplo)

# %% [markdown]
# ## O próximo passo foi amostrar imagens de raios-X de pacientes saudáveis

# %% [markdown]
# ### Para fazer isso, usei o conjunto de dados de imagens de raios X do tórax de Kaggle (Pneumonia) e coletei 25 imagens de raios X de pacientes saudáveis ( Figura 2 , à direita ). Existem vários problemas com o conjunto de dados de radiografia de tórax do Kaggle, ou seja, rótulos ruidosos / incorretos, mas serviu como um ponto de partida suficientemente bom para esta prova de conceito do detector COVID-19.

# %% [markdown]
# ## Após reunir meu conjunto de dados, fiquei com 50 imagens no total , divididas igualmente com 25 imagens de raios-X positivos para COVID-19 e 25 imagens de raios-X de pacientes saudáveis.

# %% [markdown]
# ### Implementando nosso script de treinamento COVID-19 usando Keras e TensorFlow

# %% [markdown]
# ### Agora que analisamos nosso conjunto de dados de imagens junto com a estrutura de diretórios correspondente ao nosso projeto, passemos ao ajuste fino de uma Rede Neural Convolucional para diagnosticar automaticamente o COVID-19 usando Keras, TensorFlow e aprendizado profundo.

# %%
pip3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-896908e64b2d> in <module>
# ----> 1 pip3
#
# NameError: name 'pip3' is not defined

# %%
import tensorflow
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\tensorflow\python\pywrap_tensorflow.py in <module>
#      57
# ---> 58   from tensorflow.python.pywrap_tensorflow_internal import *
#      59
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\pywrap_tensorflow_internal.py in <module>
#      27             return _mod
# ---> 28     _pywrap_tensorflow_internal = swig_import_helper()
#      29     del swig_import_helper
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\pywrap_tensorflow_internal.py in swig_import_helper()
#      23             try:
# ---> 24                 _mod = imp.load_module('_pywrap_tensorflow_internal', fp, pathname, description)
#      25             finally:
#
# ~\Anaconda3\lib\imp.py in load_module(name, file, filename, details)
#     241         else:
# --> 242             return load_dynamic(name, filename, file)
# ...

# %% [markdown]
# ## Carregar Imagens

# %%
import matplotlib.pyplot as plt
plt.imread('Matplotlib-Mapa.png')
