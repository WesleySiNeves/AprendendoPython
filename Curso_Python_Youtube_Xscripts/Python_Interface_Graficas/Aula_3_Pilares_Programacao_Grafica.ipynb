# %% [markdown]
# ## Pilares da programação Grafica

# %%
diretorio_imagens =r"F:/VersionCode/AprendendoPython/AprendendoPython/Curso_Python_Youtube_Xscripts/arquivos/"

# %%
from IPython.display import Image
Image(diretorio_imagens +'pilares_programacao_grafica.png')
