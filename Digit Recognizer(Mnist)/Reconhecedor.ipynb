# %% [markdown]
# ## Introdução
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## E feita uma operação em cada neuronio da rede ,a saida de um neuronio e a entrada do proximo
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## O objetivo e minimizar o erro (retropropagação)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Redes Neurais convolucionais Arquitetura

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Covolução é uma transformação linear , e um mapeamento de uma pequena janela , gerando uma nova matrix, a saida da camada de convolução é uma matrix de feteares( caracteristicas), essa matrix é submetida a camada de polling
# Kernel pode ser chamado tambem de filtro de convolução

# %% [markdown]
# ## Operação de convolução

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Camada Polling , é uma camada de sub amostragem, ela recebe a matriz da camada de convolução e retem as caracteristicas mais importantes ,

# %% [markdown]
# ## como a camada de polling funciona

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## depois do calculo da camada de polling , e feito encima do resultado uma trasformação da matriz gerada para um unico vetor( transposto ) uma unica coluna ,essa operação e chamada de flatten

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## para evitar o overfiting ,quando o modelo se ajusta demais ao dados e perde a capacidade de generalizar , para isso usamos a tecnica de dropout( desligar certa quantidade de neuronios
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Resumo
#
# ![image.png](data:image/png;base64,...)

# %%
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Flatten
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
import numpy as np
from matplotlib import pyplot as plt
from keras.utils import np_utils
import cv2
import os

from keras import backend as K


# K.set_image_dim_ordering('th') # Não é mais suportado nas versões mais recentes do Keras
K.tensorflow_backend.set_image_dim_ordering('th')

# %matplotlib inline

seed = 7
np.random.seed(seed)

# %% [markdown]
# ## importação dos pacotes

# %% [markdown]
# # definir o vetor de imagens , para imagens branco e preto vamos usar apenas 1 canal
# #no mnist todas as imagens são 28 x 28
# # O keras trabalha com suporte ao theano e o tensorflow
# para o theano a ordem do vetor tem como primeiro elemento o canal da imagem e depois as dimensões
# [1,28,28]
# para o tensorflow a ordem do vetor tem como elemento a
# dimensão das imagwns e depois o canal
# [28,28,1]
# vamos configurar esse vetor para o theano

# %%
K.common.set_image_dim_ordering('th')

# %% [markdown]
# # Agora vamos importar nosso dataset dividido em treino e test
# X = feteares
# Y = rotulos ou target

# %%
(X_train,Y_train),(X_test,Y_test) = mnist.load_data()
# Out:
# ...
# 11493376/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# No dataset minist saõ usn 60000 mil dados de treinos com imagens de 28 X 28, logo precisamos formartar nosso dataset
# X_train com esse formato
# (X_train.shape[0],1,28,28) ou seja , 60000 com canal na escala de cinza (1) sendo 28 X 28

# %%
 X_train.shape
# Out:
# (60000, 28, 28)

# %%
X_train = X_train.reshape(X_train.shape[0],1,28,28).astype('float32')

# %%
X_test.shape
# Out:
# (10000, 28, 28)

# %%
X_test = X_test.reshape(X_test.shape[0],1,28,28).astype('float32')

# %% [markdown]
# #Agora precisamos modificar os intervalo dos pixels do que ficar entre (0 - 255) ficar entre (0-1) ,então vamos tranformar os pixel de (0-255) para (0-1)

# %%
X_train[-1]

# %%
X_train = X_train / 255
X_test = X_test / 255

# %%
X_train[-1]
