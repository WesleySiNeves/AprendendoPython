# %% [markdown]
# # <font color='blue'>Data Science Academy - Python Fundamentos - Capítulo 9</font>
#
# ## Download: http://github.com/dsacademybr
#
# ## Mini-Projeto 2 - Análise Exploratória em Conjunto de Dados do Kaggle
#
# ## Análise 1

# %%
# Imports
import os
import subprocess
import stat
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime
sns.set(style="white")
# %matplotlib inline

# %%
# Dataset
clean_data_path = "dataset/autos.csv"
df = pd.read_csv(clean_data_path,encoding="latin-1")

# %% [markdown]
# ## Distribuição de Veículos com base no Ano de Registro

# %% [markdown]
# ## grafico de histograma

# %%
# Crie um Plot com a Distribuição de Veículos com base no Ano de Registro
df.yearOfRegistration.hist(bins =50)
plt.xlabel("Ano")
plt.ylabel("Quantidade")
plt.title("Distribuição de Veiculos com base no Ano de Registro")
plt.show()

# %% [markdown]
# data = df.yearOfRegistration.value_counts().rename_axis('ano').reset_index(name='quantidade')

# %%
plt.bar(data.ano,data.quantidade, label = 'Ano', color = 'r')
plt.legend()
plt.show()

# %%
sns.set(color_codes=True)
sns.distplot(df.yearOfRegistration,color='green')
plt.xlabel("Ano")
plt.ylabel("Quantidade")
plt.fi
color = 'blue'
plt.title("Distribuição de Veiculos com base no Ano de Registro")
plt.show()

# %%
df.groupby('yearOfRegistration').count().T
# Out:
# yearOfRegistration   1910  1915  1919  1920  1923  1925  1927  1928  1929  \
# dateCrawled           100     1     1     1     2     1     1     2     5
# name                  100     1     1     1     2     1     1     2     5
# seller                100     1     1     1     2     1     1     2     5
# offerType             100     1     1     1     2     1     1     2     5
# price                 100     1     1     1     2     1     1     2     5
# abtest                100     1     1     1     2     1     1     2     5
# vehicleType           100     1     1     1     2     1     1     2     5
# gearbox               100     1     1     1     2     1     1     2     5
# powerPS               100     1     1     1     2     1     1     2     5
# model                 100     1     1     1     2     1     1     2     5
# kilometer             100     1     1     1     2     1     1     2     5
# monthOfRegistration   100     1     1     1     2     1     1     2     5
# fuelType               98     1     1     0     2     1     1     2     5
# brand                 100     1     1     1     2     1     1     2     5
# notRepairedDamage     100     1     1     1     2     1     1     2     5
# dateCreated           100     1     1     1     2     1     1     2     5
# postalCode            100     1     1     1     2     1     1     2     5
# lastSeen              100     1     1     1     2     1     1     2     5
# yearOfCreation        100     1     1     1     2     1     1     2     5
# yearCrawled           100     1     1     1     2     1     1     2     5
# monthOfCreation       100     1     1     1     2     1     1     2     5
# monthCrawled          100     1     1     1     2     1     1     2     5
# NoOfDaysOnline        100     1     1     1     2     1     1     2     5
# NoOfHrsOnline         100     1     1     1     2     1     1     2     5
# yearsOld              100     1     1     1     2     1     1     2     5
# monthsOld             100     1     1     1     2     1     1     2     5
#
# yearOfRegistration   1930  ...   2007   2008   2009  2010  2011  2012  2013  \
# dateCrawled             2  ...  15732  13506  11850  7696  6031  3714  1763
# name                    2  ...  15732  13506  11850  7696  6031  3714  1763
# seller                  2  ...  15732  13506  11850  7696  6031  3714  1763
# offerType               2  ...  15732  13506  11850  7696  6031  3714  1763
# price                   2  ...  15732  13506  11850  7696  6031  3714  1763
# abtest                  2  ...  15732  13506  11850  7696  6031  3714  1763
# vehicleType             2  ...  15732  13506  11850  7696  6031  3714  1763
# gearbox                 2  ...  15732  13506  11850  7696  6031  3714  1763
# powerPS                 2  ...  15732  13506  11850  7696  6031  3714  1763
# model                   2  ...  15732  13506  11850  7696  6031  3714  1763
# kilometer               2  ...  15732  13506  11850  7696  6031  3714  1763
# monthOfRegistration     2  ...  15732  13506  11850  7696  6031  3714  1763
# fuelType                2  ...  15728  13503  11849  7695  6030  3713  1762
# brand                   2  ...  15732  13506  11850  7696  6031  3714  1763
# notRepairedDamage       2  ...  15732  13506  11850  7696  6031  3714  1763
# dateCreated             2  ...  15732  13506  11850  7696  6031  3714  1763
# postalCode              2  ...  15732  13506  11850  7696  6031  3714  1763
# lastSeen                2  ...  15732  13506  11850  7696  6031  3714  1763
# yearOfCreation          2  ...  15732  13506  11850  7696  6031  3714  1763
# yearCrawled             2  ...  15732  13506  11850  7696  6031  3714  1763
# monthOfCreation         2  ...  15732  13506  11850  7696  6031  3714  1763
# monthCrawled            2  ...  15732  13506  11850  7696  6031  3714  1763
# NoOfDaysOnline          2  ...  15732  13506  11850  7696  6031  3714  1763
# NoOfHrsOnline           2  ...  15732  13506  11850  7696  6031  3714  1763
# yearsOld                2  ...  15732  13506  11850  7696  6031  3714  1763
# monthsOld               2  ...  15732  13506  11850  7696  6031  3714  1763
#
# yearOfRegistration   2014  2015  2016
# dateCrawled           986   641  8093
# name                  986   641  8093
# seller                986   641  8093
# offerType             986   641  8093
# price                 986   641  8093
# abtest                986   641  8093
# vehicleType           986   641  8093
# gearbox               986   641  8093
# powerPS               986   641  8093
# model                 986   641  8093
# kilometer             986   641  8093
# monthOfRegistration   986   641  8093
# fuelType              984   638  8084
# brand                 986   641  8093
# notRepairedDamage     986   641  8093
# dateCreated           986   641  8093
# postalCode            986   641  8093
# lastSeen              986   641  8093
# yearOfCreation        986   641  8093
# yearCrawled           986   641  8093
# monthOfCreation       986   641  8093
# monthCrawled          986   641  8093
# NoOfDaysOnline        986   641  8093
# NoOfHrsOnline         986   641  8093
# yearsOld              986   641  8093
# monthsOld             986   641  8093
#
# [26 rows x 93 columns]

# %%
# Crie um Plot com a Distribuição de Veículos com base no Ano de Registro

# %%
# Salvando o plot
fig.savefig("plots/Analise1/vehicle-distribution.png")

# %% [markdown]
# ## Variação da faixa de preço pelo tipo de veículo

# %%
red_square = dict(markerfacecolor='r', marker='s')
fig5, ax5 = plt.subplots()
ax5.set_title('Horizontal Boxes')
ax5.boxplot(df.price, vert=True, flierprops=red_square)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x15d510c1548>,
#   <matplotlib.lines.Line2D at 0x15d510c17c8>],
#  'caps': [<matplotlib.lines.Line2D at 0x15d510b9908>,
#   <matplotlib.lines.Line2D at 0x15d510aaec8>],
#  'boxes': [<matplotlib.lines.Line2D at 0x15d510d7b48>],
#  'medians': [<matplotlib.lines.Line2D at 0x15d510a2848>],
#  'fliers': [<matplotlib.lines.Line2D at 0x15d51099e08>],
#  'means': []}

# %%
# Crie um Boxplot para avaliar os outliers

# %%
# Salvando o plot
fig.savefig("plots/Analise1/price-vehicleType-boxplot.png")

# %% [markdown]
# ## Contagem total de veículos à venda conforme o tipo de veículo

# %%
# Crie um Count Plot que mostre o número de veículos pertencentes a cada categoria

# %%
# Salvando o plot
g.savefig("plots/Analise1/count-vehicleType.png")

# %% [markdown]
# Conheça a Formação Cientista de Dados, um programa completo, 100% online e 100% em português, com 340 horas, mais de 1.200 aulas em vídeos e 26 projetos, que vão ajudá-lo a se tornar um dos profissionais mais cobiçados do mercado de análise de dados. Clique no link abaixo, faça sua inscrição, comece hoje mesmo e aumente sua empregabilidade:
#
# https://www.datascienceacademy.com.br/pages/formacao-cientista-de-dados

# %% [markdown]
# # Fim

# %% [markdown]
# ### Obrigado - Data Science Academy - <a href="http://facebook.com/dsacademybr">facebook.com/dsacademybr</a>
