# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Forma de acionar 100 a cada elemento do Array

# %%
diretorio_imagens =r'D:\Wesley\VersionCode\AprendendoPython\AprendendoPython\pyData\Pandas\Arquivos'

# %%
from IPython.display import Image
Image(diretorio_imagens +'\Pandas_series.PNG')

# %%
a = (10,20,30,40,50,60,70)
print(type(a))

b = np.asarray(a)

print(type(b))

print(b)
print(b +100)
# Out:
# <class 'tuple'>
# <class 'numpy.ndarray'>
# [10 20 30 40 50 60 70]
# [110 120 130 140 150 160 170]

# %%
pd.Series([10,20,30,40])
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
pd.Series([10,20,30,40],index=[1,2,3,5])
# Out:
# 1    10
# 2    20
# 3    30
# 5    40
# dtype: int64

# %%
pd.Series([10,20,30,40],index=['a','b','c','d'])
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64
