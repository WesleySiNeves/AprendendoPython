# %%
import pandas as pd
import numpy as np

import matplotlib as mt

# %matplotlib inline

# %%
r = np.random.randn(10,3)

dataframe  = pd.DataFrame(r,columns=['Coluna1','Coluna2','Coluna3'])

dataframe
# Out:
#     Coluna1   Coluna2   Coluna3
# 0  1.733634 -0.912851 -1.449433
# 1  0.958351 -0.016583 -0.590294
# 2 -0.364425 -0.254474  0.877661
# 3  0.192253  0.692059  1.760404
# 4 -1.193891  0.370039 -0.224738
# 5 -1.726965  1.220328  0.683525
# 6  0.329075 -0.364491 -0.639475
# 7 -1.760622  0.152604  0.319839
# 8 -0.898001  2.002459 -0.657677
# 9 -0.234246 -0.964495  1.178357

# %%
dataframe['Coluna1'].plot.line()

# %%
datas = pd.date_range('20190101',periods=1000,freq='D')

# %%
novo_dataframe = pd.DataFrame(dataframe,index=datas)

novo_dataframe[0:10]
# Out:
#             Coluna1  Coluna2  Coluna3
# 2019-01-01      NaN      NaN      NaN
# 2019-01-02      NaN      NaN      NaN
# 2019-01-03      NaN      NaN      NaN
# 2019-01-04      NaN      NaN      NaN
# 2019-01-05      NaN      NaN      NaN
# 2019-01-06      NaN      NaN      NaN
# 2019-01-07      NaN      NaN      NaN
# 2019-01-08      NaN      NaN      NaN
# 2019-01-09      NaN      NaN      NaN
# 2019-01-10      NaN      NaN      NaN
